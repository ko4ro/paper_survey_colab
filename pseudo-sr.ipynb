# %% [markdown]
# # pseudo-sr : Unpaired Image Super-Resolution using Pseudo-Supervision.

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://github.com/yoon28/pseudo-sr"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
#   <td>
#     <a href="https://openaccess.thecvf.com/content_CVPR_2020/papers/Maeda_Unpaired_Image_Super-Resolution_Using_Pseudo-Supervision_CVPR_2020_paper.pdf"><img src="https://www.tensorflow.org/images/download_logo_32px.png" />Download paper</a>
#   </td>
# </table>

# %%
# !git clone https://github.com/yoon28/pseudo-sr.git
# Out:
# Cloning into 'pseudo-sr'...
# remote: Enumerating objects: 50, done.
# remote: Total 50 (delta 0), reused 0 (delta 0), pack-reused 50
# Unpacking objects: 100% (50/50), done.

# %%
import os
os.chdir('pseudo-sr/')

# %%
# !pip install yacs

# %%
! python train.py configs/faces.yaml --port 12121
# Out:
# Traceback (most recent call last):
#   File "train.py", line 15, in <module>
#     from models.face_trainer import Face_Model
# ModuleNotFoundError: No module named 'models.face_trainer'
